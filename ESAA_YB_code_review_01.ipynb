# %% [markdown]
# <a href="https://colab.research.google.com/github/alscop/ESAA-25-2/blob/main/ESAA_YB_code_review_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 수상작 리뷰
# (https://www.kaggle.com/code/gusthema/spaceship-titanic-with-tfdf#Prepare-the-dataset)

# %% [markdown]
# # 주제 및 데이터
#
# Spaceship Titanic with TFDF
#
# Random Forest model 트레이닝.

# %% [markdown]
# # 코드 리뷰 : 각 분석 과정의 코드 흐름을 요약 정리(EDA, 전처리, 모델링 등)
#
# EDA
# - bar chart
# - Numerical data distribution.
#
# 전처리
# - 트레이닝에 중요하지 않은 피처 삭제(승객 아이디, 이름)
# - 결측치 확인. TF-DF에서 모두 natively support -> 굳이 전처리 필요X
# - boolean fields TF-DF에서 처리 불가 -> int로 변경. 결측치는 0으로 변경.
# - Cabin 칼럼을 Deck, Cabin_num, Slide 칼럼으로 나눈 뒤 Cabin 칼럼은 삭제.
# - pd.DataFrame에서 tf.data.Dataset으로 변경(TensorFlow Datasets format) : GPUs, TPUs 등 높은 효용 보이는 라이브러리.
#
#
# 모델링 - tfdf 이용
# - RandomForestModel
#   -
# - GradientBoostedTreesModel
# - CartModel
# - DistributedGradientBoostedTreesModel
#
#
# - trian
# - visualize : tree-based model은 쉽게 시각화 가능.
# - evaluate 순으로 .

# %% [markdown]
# # 차별점 및 배울점 : 새롭게 얻은 인사이트, 인상깊었던 점

# %% [markdown]
# tfdf 사용법과 특징에 대해 알게됨.
# tfdf 모델링의 특징에 따라 전처리 과정에 적용해야 하는 주의점이 명확함, boolean은 꼭 int로 변경 필요.
